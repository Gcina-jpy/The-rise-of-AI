# %% [markdown]
# This project explores the remarkable growth of Artificial Intelligence (AI) from 2018 to 2025, highlighting its transformative impact on various sectors,more especially healthcare. By analyzing key metrics such as AI software revenue, market value, and adoption rates, we can better understand how organizations are embracing AI and the resulting implications for jobs and industries.

# %%
import pandas as pd

# %%
df = pd.read_csv('The Rise Of Artificial Intellegence2.csv')

# %% [markdown]
# Overview of the Data on the Rise of Artificial Intelligence
# This dataset provides an analysis of key metrics tracking the development and impact of Artificial Intelligence (AI) from 2018 to 2025. It covers several areas of AI adoption, revenue growth, market value, job impacts, and AI's integration into industries like healthcare.

# %% [markdown]
# Overview of the Data on the Rise of Artificial Intelligence
# This dataset provides an analysis of key metrics tracking the development and impact of Artificial Intelligence (AI) from 2018 to 2025. It covers several areas of AI adoption, revenue growth, market value, job impacts, and AI's integration into industries like healthcare.
#
# Key Columns in the Dataset:
# AI Software Revenue: Tracks the annual revenue generated by AI software, growing from $10.1 billion in 2018 to a projected $126 billion in 2025.
# Global AI Market Value: Represents the overall market value of AI, which rises from $29.5 billion in 2018 to a staggering $1.81 trillion in 2025.
# AI Adoption Rates: Shows the percentage of organizations adopting AI, growing from 10% in 2018 to 63% by 2025.
# Job Impact: Includes the number of jobs eliminated and created by AI, highlighting concerns about job displacement in industries like transportation, retail, and manufacturing.
# AI in Healthcare: Shows AI's contribution to healthcare, increasing from $461 billion in 2018 to $500 billion by 2025.
# Digital Voice Assistants: Tracks the adoption of AI-powered digital voice assistants, increasing from 1.5 billion devices in 2018 to 5.5 billion devices by 2025.

# %%
df.head()
# Out:
#    Year  AI Software Revenue(in Billions)  \
# 0  2018                             10.10
# 1  2019                             14.69
# 2  2020                             22.59
# 3  2021                             34.87
# 4  2022                             51.27
#
#    Global AI Market Value(in Billions) AI Adoption (%) Organizations Using AI  \
# 0                                 29.5             10%                    35%
# 1                                 35.0             20%                    37%
# 2                                 45.0             30%                    40%
# 3                                 65.0             35%                    42%
# 4                                140.0             35%                    45%
#
#   Organizations Planning to Implement AI  \
# 0                                    40%
# 1                                    42%
# 2                                    45%
# 3                                    47%
# ...

# %%
empty_columns = df.columns[df.isnull().all()]


df.drop(empty_columns, axis=1, inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 22 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   Year                                                            8 non-null      int64
#  1   AI Software Revenue(in Billions)                                8 non-null      float64
#  2   Global AI Market Value(in Billions)                             8 non-null      float64
#  3   AI Adoption (%)                                                 8 non-null      object
#  4   Organizations Using AI                                          8 non-null      object
#  5   Organizations Planning to Implement AI                          8 non-null      object
#  6   Global Expectation for AI Adoption (%)                          8 non-null      object
# ...

# %%
missing_values = df.isnull().sum()
print(missing_values[missing_values > 0])
# Out:
# Series([], dtype: int64)

# %%
import matplotlib.pyplot as plt

# %%
# Bar plot for AI Contribution to Healthcare over Years
plt.figure(figsize=(10, 6))
plt.bar(df['Year'], df['AI Contribution to Healthcare(in Billions)'], color='orange')
plt.title('AI Contribution to Healthcare Over Time')
plt.xlabel('Year')
plt.ylabel('Contribution to Healthcare (in Billions)')
plt.xticks(df['Year'])
plt.show()

# %% [markdown]
# Bar Graph Explanation: AI's Contribution to Healthcare (2018-2025)
# The bar graph visualizes the increasing contribution of AI to the healthcare industry from 2018 to 2025. Here’s what it shows:
#
# 2018: AI’s contribution to healthcare was $461 billion. This was the starting point where AI began to be adopted for healthcare applications such as diagnostics, predictive analytics, and medical imaging.
#
# 2019-2022: Over these years, the contribution steadily increased, reaching $480 billion by 2022. This gradual rise reflects healthcare institutions integrating AI for tasks like patient monitoring, automated diagnostics, and operational efficiency.
#
# 2023-2025: The contribution continues to grow, hitting $500 billion by 2025. This marks a significant increase, driven by innovations like AI-assisted surgeries, personalized medicine, and predictive health analytics. The graph shows consistent adoption, with healthcare professionals leveraging AI to improve patient outcomes, reduce medical errors, and streamline hospital operations.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

plt.plot(df['Year'], df['AI Software Revenue(in Billions)'], marker='o', color='orange', label='AI Software Revenue')

plt.plot(df['Year'], df['Global AI Market Value(in Billions)'], marker='o', color='green', label='Global AI Market Value')


plt.title('Rise of AI Metrics Over Time')
plt.xlabel('Year')
plt.ylabel('Value (in Billions)')
plt.xticks(df['Year'])
plt.grid()


plt.legend()


plt.show()

# %% [markdown]
# The line graph visually captures the impressive rise of Artificial Intelligence metrics from 2018 to 2025, highlighting two key areas: AI Software Revenue and Global AI Market Value. As we progress through the years, we can see a steady upward trend in both metrics, reflecting the growing adoption and integration of AI technologies across various industries. The orange line representing AI Software Revenue shows significant growth, indicating that businesses are increasingly investing in AI solutions to enhance their operations. Similarly, the green line for Global AI Market Value illustrates the expanding market and the heightened interest in AI innovations. This graph not only underscores the rapid evolution of AI but also emphasizes its critical role in shaping the future of technology and business, suggesting that as we move forward, AI will continue to be a driving force in economic development and operational efficiency.
